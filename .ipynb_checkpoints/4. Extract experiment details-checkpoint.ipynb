# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from StringIO import StringIO

# Visualization
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')

# %%
# Read every single row until fnirs data
debug = 0:
for i in range(31):
    arow = pd.read_csv("cQuyen.TXT", skiprows=i, nrows = 1, sep='\t', 
                       header=None, index_col=0)
    if debug:
        print('row num. %d\n' % (i))
        print '------------------------------'
        print arow
        print ''
    if arow.index == 'Loop':
        print arow
# Out:
# row num. 0
#
# ------------------------------
#                             1             2   3
# 0
#  [File Information]       NaN   [Data Line]  36
#
# row num. 1
#
# ------------------------------
#                                  1
# 0
# Measured Date  2016/04/02 16:27:54
#
# row num. 2
#
# ------------------------------
#     1        2     3
# 0
# ID  1  Version  5.01
#
# row num. 3
#
# ------------------------------
#            1             2          3
# 0
# Name  cQuyen  [HeaderType]  5.01/2.01
#
# row num. 4
#
# ------------------------------
#           1
# 0
# Comment NaN
#
# row num. 5
#
# ------------------------------
# Empty DataFrame
# Columns: []
# Index: [[Measurement Info.]]
#
# row num. 6
#
# ------------------------------
#                   1
# 0
# Holder Location  19
#
# row num. 7
#
# ------------------------------
#                      1
# 0
# Block Design  Off
#
# row num. 8
#
# ------------------------------
#                 1
# 0
# Pre.Rest Time  30
#
# row num. 9
#
# ------------------------------
#              1
# 0
# Task Time  180
# row num. 10
#
# ------------------------------
#                 1
# 0
# Pos.Rest Time  30
#
# row num. 11
#
# ------------------------------
#       1
# 0
# Loop  5
#
# row num. 12
#
# ------------------------------
#            1
# 0
# Averaging  1
#
# row num. 13
#
# ------------------------------
#                   1
# 0
# Total Points  22394
#
# row num. 14
#
# ------------------------------
# Empty DataFrame
# Columns: []
# Index: [[.INF File]]
#
# row num. 15
#
# ------------------------------
#                        1
# 0
# Filename  thuong0402.INF
#
# row num. 16
#
# ------------------------------
# Empty DataFrame
# Columns: []
# Index: [[Condition-1]]
#
# row num. 17
#
# ------------------------------
#                 1
# 0
# HV Switching  OFF
#
# row num. 18
#
# ------------------------------
# Empty DataFrame
# Columns: []
# Index: [ R1 ,R2 ,R3 ,R4 ,R5 ,R6 ,R7 ,R8 ]
#
# row num. 19
#
# ------------------------------
# Empty DataFrame
# Columns: []
# Index: [   0.00,  0.00,  0.00,  0.00,462.00,459.00,  0.00,529.00]
#
# row num. 20
#
# ------------------------------
# Empty DataFrame
# Columns: []
# Index: [ Gain(X1,X4,X16,X64)]
#
# row num. 21
# ------------------------------
# Empty DataFrame
# Columns: []
# Index: [ R1 ,R2 ,R3 ,R4 ,R5 ,R6 ,R7 ,R8 ]
#
# row num. 22
#
# ------------------------------
# Empty DataFrame
# Columns: []
# Index: [ 1,1,1,1,1,1,1,1]
#
# row num. 23
#
# ------------------------------
# Empty DataFrame
# Columns: []
# Index: [[Analysis Condition]]
#
# row num. 24
#
# ------------------------------
#                               1
# 0
# Smoothed Type  None
#
# row num. 25
#
# ------------------------------
#                  1
# 0
# Smoothed Points  0
#
# row num. 26
#
# ------------------------------
#                1
# 0
# Smoothed Loop  0
#
# row num. 27
#
# ------------------------------
#                                 1
# 0
# Baseline Method  None
#
# row num. 28
#
# ------------------------------
#                     1
# 0
# Baseline location NaN
#
# row num. 29
#
# ------------------------------
# Empty DataFrame
# Columns: []
# Index: [[Text Info.]]
#
# row num. 30
#
# ------------------------------
#                             1         2   3          4         5
# 0
# Output Mode  Continious        Task No. NaN  Data Type  Hb

# %%
arow = pd.read_csv("cQuyen.TXT", skiprows=4, nrows = 1, sep='\t', header=None)
arow
# Out:
#          0   1
# 0  Comment NaN

# %%
# Out:
# (1, 2)

# %%
arow.
# Out:
#          0   1
# 0  Comment NaN
